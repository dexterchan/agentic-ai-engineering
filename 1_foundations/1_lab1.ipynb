# %% [markdown]
# # Welcome to the start of your adventure in Agentic AI

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Are you ready for action??</h2>
#             <span style="color:#ff7800;">Have you completed all the setup steps in the <a href="../setup/">setup</a> folder?<br/>
#             Have you checked out the guides in the <a href="../guides/01_intro.ipynb">guides</a> folder?<br/>
#             Well in that case, you're ready!!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">This code is a live resource - keep an eye out for my updates</h2>
#             <span style="color:#00bfff;">I push updates regularly. As people ask questions or have problems, I add more examples and improve explanations. As a result, the code below might not be identical to the videos, as I've added more steps and better comments. Consider this like an interactive book that accompanies the lectures.<br/><br/>
#             I try to send emails regularly with important updates related to the course. You can find this in the 'Announcements' section of Udemy in the left sidebar. You can also choose to receive my emails via your Notification Settings in Udemy. I'm respectful of your inbox and always try to add value with my emails!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### And please do remember to contact me if I can help
#
# And I love to connect: https://www.linkedin.com/in/eddonner/
#
#
# ### New to Notebooks like this one? Head over to the guides folder!
#
# Just to check you've already added the Python and Jupyter extensions to Cursor, if not already installed:
# - Open extensions (View >> extensions)
# - Search for python, and when the results show, click on the ms-python one, and Install it if not already installed
# - Search for jupyter, and when the results show, click on the Microsoft one, and Install it if not already installed
# Then View >> Explorer to bring back the File Explorer.
#
# And then:
# 1. Click where it says "Select Kernel" near the top right, and select the option called `.venv (Python 3.12.9)` or similar, which should be the first choice or the most prominent choice. You may need to choose "Python Environments" first.
# 2. Click in each "cell" below, starting with the cell immediately below this text, and press Shift+Enter to run
# 3. Enjoy!
#
# After you click "Select Kernel", if there is no option like `.venv (Python 3.12.9)` then please do the following:
# 1. On Mac: From the Cursor menu, choose Settings >> VS Code Settings (NOTE: be sure to select `VSCode Settings` not `Cursor Settings`);
# On Windows PC: From the File menu, choose Preferences >> VS Code Settings(NOTE: be sure to select `VSCode Settings` not `Cursor Settings`)
# 2. In the Settings search bar, type "venv"
# 3. In the field "Path to folder with a list of Virtual Environments" put the path to the project root, like C:\Users\username\projects\agents (on a Windows PC) or /Users/username/projects/agents (on Mac or Linux).
# And then try again.
#
# Having problems with missing Python versions in that list? Have you ever used Anaconda before? It might be interferring. Quit Cursor, bring up a new command line, and make sure that your Anaconda environment is deactivated:
# `conda deactivate`
# And if you still have any problems with conda and python versions, it's possible that you will need to run this too:
# `conda config --set auto_activate_base false`
# and then from within the Agents directory, you should be able to run `uv python list` and see the Python 3.12 version.

# %%
# First let's do an import
from dotenv import load_dotenv

# %%
# Next it's time to load the API keys into environment variables

load_dotenv(override=True)
# Out:
# True

# %%
# Check the keys

import os
openai_api_key = os.getenv('OPENAI_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set - please head to the troubleshooting guide in the setup folder")
# Out:
# OpenAI API Key exists and begins sk-QQoSd

# %%
# And now - the all important import statement
# If you get an import error - head over to troubleshooting guide

from openai import OpenAI

# %%
# And now we'll create an instance of the OpenAI class
# If you're not sure what it means to create an instance of a class - head over to the guides folder!
# If you get a NameError - head over to the guides folder to learn about NameErrors

openai = OpenAI()

# %%
# Create a list of messages in the familiar OpenAI format

messages = [{"role": "user", "content": "What is 2+2?"}]

# %%
# And now call it! Any problems, head to the troubleshooting guide
# This uses GPT 4.1 nano, the incredibly cheap model

response = openai.chat.completions.create(
    model="gpt-4.1-nano",
    messages=messages
)

print(response.choices[0].message.content)
# Out:
# 2 + 2 equals 4.

# %%
# And now - let's ask for a question:

question = "Please propose a hard, challenging question to assess someone's IQ. Respond only with the question."
messages = [{"role": "user", "content": question}]

# %%
# ask it - this uses GPT 4.1 mini, still cheap but more powerful than nano

response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

question = response.choices[0].message.content

print(question)
# Out:
# If two trains start from points A and B, which are 300 miles apart, traveling toward each other at speeds of 40 mph and 60 mph respectively, a bird starts flying from the front of the first train toward the second train at 90 mph, turns around instantly upon reaching the second train, and continues this back-and-forth flight until the trains meet. How many miles does the bird travel in total?

# %%
# form a new messages list
messages = [{"role": "user", "content": question}]

# %%
# Ask it again

response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

answer = response.choices[0].message.content
print(answer)
# Out:
# Let's analyze the problem step-by-step.
#
# ---
#
# ### Given:
# - Distance between two trains: \(300\) miles
# - Speed of train A: \(40\) mph (starting from point A)
# - Speed of train B: \(60\) mph (starting from point B)
# - Speed of the bird: \(90\) mph
# - Bird flies back and forth between the trains until they meet
#
# ---
#
# ### Step 1: Find the time until the trains meet
#
# The trains are moving toward each other, so their relative speed is:
# \[
# 40 + 60 = 100 \text{ mph}
# \]
#
# Time until they meet:
# \[
# t = \frac{\text{distance}}{\text{relative speed}} = \frac{300}{100} = 3 \text{ hours}
# \]
#
# ---
#
# ### Step 2: Calculate how far the bird travels
#
# Since the bird is flying constantly at \(90\) mph and flies for the entire time until the trains meet (3 hours):
#
# \[
# \text{distance traveled by bird} = \text{speed} \times \text{time} = 90 \times 3 = 270 \text{ miles}
# \]
#
# ---
#
# ### **Answer:**
#
# \[
# \boxed{270 \text{ miles}}
# \]
#
# The bird travels a total of **270 miles** before the trains meet.

# %%
from IPython.display import Markdown, display

display(Markdown(answer))
# Out:
# Let's analyze the problem step-by-step.
#
# ---
#
# ### Given:
# - Distance between two trains: \(300\) miles
# - Speed of train A: \(40\) mph (starting from point A)
# - Speed of train B: \(60\) mph (starting from point B)
# - Speed of the bird: \(90\) mph
# - Bird flies back and forth between the trains until they meet
#
# ---
#
# ### Step 1: Find the time until the trains meet
#
# The trains are moving toward each other, so their relative speed is:
# \[
# 40 + 60 = 100 \text{ mph}
# \]
#
# Time until they meet:
# \[
# t = \frac{\text{distance}}{\text{relative speed}} = \frac{300}{100} = 3 \text{ hours}
# \]
#
# ---
#
# ### Step 2: Calculate how far the bird travels
#
# Since the bird is flying constantly at \(90\) mph and flies for the entire time until the trains meet (3 hours):
#
# \[
# \text{distance traveled by bird} = \text{speed} \times \text{time} = 90 \times 3 = 270 \text{ miles}
# \]
#
# ---
#
# ### **Answer:**
#
# \[
# \boxed{270 \text{ miles}}
# \]
#
# The bird travels a total of **270 miles** before the trains meet.

# %% [markdown]
# # Congratulations!
#
# That was a small, simple step in the direction of Agentic AI, with your new environment!
#
# Next time things get more interesting...

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Now try this commercial application:<br/>
#             First ask the LLM to pick a business area that might be worth exploring for an Agentic AI opportunity.<br/>
#             Then ask the LLM to present a pain-point in that industry - something challenging that might be ripe for an Agentic solution.<br/>
#             Finally have 3 third LLM call propose the Agentic AI solution.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# First create the messages:

messages = [{"role": "user", "content": "Please pick a business area that might be worth exploring for an agentic AI opportunity."}]

# Then make the first call:

response = openai.chat.completions.create(messages=messages, model="gpt-4o-mini")

# Then read the business idea:

business_idea = response.choices[0].message.content

display(Markdown(business_idea))
messages.append({"role": "assistant", "content": business_idea})

# And repeat!

messages.append({"role": "user", "content": "please present a pain point for that industry - something challenging that might be ripe for an agentic AI solution"})

response = openai.chat.completions.create(messages=messages, model="gpt-4o-mini")

pain_point = response.choices[0].message.content

display(Markdown(pain_point))
messages.append({"role": "assistant", "content": pain_point})

messages.append({"role": "user", "content": "please propose a solution to that pain point"})

response = openai.chat.completions.create(messages=messages, model="gpt-4o-mini")

solution = response.choices[0].message.content

display(Markdown(solution))
# Out:
# One promising business area for exploring agentic AI opportunities is **Personalized Health Management**. This sector encompasses a wide range of applications that can leverage AI capabilities to provide tailored health services to individuals.
#
# ### Key Areas of Exploration:
#
# 1. **Chronic Disease Management**:
#    - AI can help monitor patients with chronic conditions (e.g., diabetes, hypertension) by analyzing real-time data from wearable devices and providing personalized recommendations for diet, medication adherence, and lifestyle changes.
#
# 2. **Mental Health Support**:
#    - Agentic AI could offer real-time emotional support through chatbots or virtual therapists that use natural language processing to engage with users, assess their mood, and suggest coping strategies or resources based on their unique situations.
#
# 3. **Preventive Health and Wellness**:
#    - AI can curate personalized wellness plans, incorporating fitness, nutrition, and mental health strategies tailored to an individual's lifestyle, preferences, and health data, helping to prevent future health issues.
#
# 4. **Telehealth Enhancement**:
#    - Integrating AI into telehealth platforms could facilitate a more interactive experience, where AI assists healthcare providers in analyzing patient history, symptoms, and preferences to recommend individualized treatment plans.
#
# 5. **Pharmaceutical Personalization**:
#    - AI could be used to analyze genetic information and patient histories to tailor drug prescriptions, optimizing efficacy and minimizing side effects for each individual.
#
# ### Key Benefits:
#
# - **Scalability**: Personalized health management solutions can easily be scaled to serve a large number of patients without requiring proportional increases in human resources.
# - **Accessibility**: AI-driven solutions can make personalized health recommendations more accessible to a broader population, including underserved communities where healthcare resources may be limited.
# - **Data-Driven Insights**: By utilizing massive datasets, AI can uncover patterns and correlations that human providers may overlook, enhancing the quality of care.
#
# ### Challenges to Consider:
#
# - **Data Privacy and Security**: Managing sensitive health data securely while maintaining patient privacy is paramount.
# - **Regulatory Compliance**: Navigating the complex landscape of healthcare regulations and ensuring compliance with health standards (like HIPAA in the U.S.) is critical.
# - **Trust and Adoption**: Encouraging users to trust AI-driven recommendations and ensuring healthcare professionals are on board with using these tools effectively.
#
# By developing agentic AI solutions in personalized health management, businesses can significantly enhance patient outcomes and engagement while reducing healthcare costs in the long run.
# One significant pain point in the **Personalized Health Management** industry is the **fragmentation of patient data**. Patients often receive care from multiple healthcare providers, including primary care physicians, specialists, and mental health professionals. Each of these providers may use different systems and protocols for managing patient information, leading to silos of data that hinder effective communication and comprehensive care.
#
# ### Challenges of Data Fragmentation:
#
# 1. **Incomplete Patient Profiles**: A lack of centralized data can result in providers not having access to the full scope of a patient's medical history, which can lead to misdiagnoses, inappropriate treatments, and medication errors.
#
# 2. **Inefficiency in Care Coordination**: Care teams may struggle to collaborate effectively due to disparate systems, leading to duplicated tests, inconsistent treatment plans, and delayed interventions.
#
# 3. **Patient Frustration**: Patients often have to repeatedly provide their medical history to different providers, undermining their experience and potentially leading to errors.
#
# 4. **Inability to Personalize Health Interventions**: Without a comprehensive view of a patient's health data, it becomes challenging to create truly personalized health management plans that take into account various factors like past treatments, medication adherence, lifestyle choices, and social determinants of health.
#
# ### Opportunity for Agentic AI Solution:
#
# **Unified Health Data Aggregator**: An agentic AI solution could act as an intelligent health data aggregator that seamlessly connects and analyzes data from various healthcare systems, wearable devices, and patient-reported outcomes. Here’s how it could work:
#
# - **Data Integration**: The AI would aggregate data from electronic health records (EHRs), lab results, fitness trackers, and even genetic information to create a unified and comprehensive patient profile.
#
# - **Contextual Analysis**: Using natural language processing and data analytics, the AI could evaluate the patient's data in real-time to identify trends, flag potential health risks, and provide actionable insights for both patients and providers.
#
# - **Proactive Health Management**: The AI could proactively suggest personalized health interventions and care plans based on the aggregated data, ensuring that all stakeholders are informed and aligned.
#
# - **Secure Data Sharing**: Utilizing advanced encryption and compliance with health regulations, the AI system could facilitate secure data sharing among various providers while maintaining patient privacy.
#
# By addressing the challenge of data fragmentation, this agentic AI solution could significantly enhance care coordination, improve patient outcomes, and lead to a more personalized and efficient healthcare experience.
# ### Proposed Solution: Unified Health Data Aggregator Platform (UHDA)
#
# **Overview:**
# The Unified Health Data Aggregator (UHDA) is an agentic AI-driven platform designed to integrate, analyze, and present a comprehensive view of patient health data, regardless of where it originates. The platform aims to bridge the gaps between different healthcare providers, systems, and patient-generated data, ultimately enhancing care coordination, personalizing health management, and improving health outcomes.
#
# ### Key Features of the UHDA
#
# 1. **Data Integration and Interoperability**:
#    - **Connectors for EHRs**: Develop APIs or connectors that allow the UHDA to integrate with various Electronic Health Record (EHR) systems, lab databases, and health information exchanges, facilitating seamless data transfer.
#    - **Wearable Device Compatibility**: Include integration capabilities for data from popular wearable devices and health apps (e.g., Fitbit, Apple Health, etc.) to monitor real-time health metrics.
#
# 2. **Centralized Patient Profiles**:
#    - **Comprehensive Dashboard**: Create a user-friendly dashboard where healthcare providers can view a holistic profile of the patient, including medical history, treatment plans, medications, allergies, and lifestyle factors.
#    - **Patient Control**: Allow patients to manage their data-sharing preferences, enabling them to selectively share their health information with different providers.
#
# 3. **AI-Enhanced Insights**:
#    - **Predictive Analytics**: Utilize machine learning algorithms to analyze patterns in a patient’s historical data, identifying potential health risks and suggesting preemptive interventions.
#    - **Personalized Recommendations**: Provide tailored health management plans based on aggregated data, including medication reminders, dietary suggestions, and activity recommendations.
#
# 4. **Care Coordination Tools**:
#    - **Communication Platform**: Develop secure messaging features that enable care teams to communicate directly through the platform, facilitating collaboration and quick decision-making.
#    - **Task Management**: Implement task and reminder features for healthcare providers to ensure follow-ups and care coordination are efficiently managed.
#
# 5. **Regulatory Compliance and Security**:
#    - **Data Encryption**: Employ robust encryption techniques to protect patient data and ensure that the platform complies with healthcare regulations like HIPAA.
#    - **Access Control**: Implement strict access controls, allowing only authorized personnel to access sensitive information based on patients’ consent.
#
# 6. **Patient Engagement and Education**:
#    - **Patient Portal**: Create a user-friendly portal for patients where they can view their health data, receive personalized health education resources, and track their progress.
#    - **Gamification Elements**: Incorporate gamified features to encourage patients to engage with their health management actively, such as tracking their fitness goals or completing educational modules about their conditions.
#
# ### Implementation Steps
#
# 1. **Pilot Testing**: Launch a pilot program with a small group of healthcare providers to test the integration and functionality of the UHDA. Gather feedback for refinement.
#
# 2. **Partnership Development**: Collaborate with healthcare organizations, technology firms, and data management companies to establish partnerships for data sharing and integration.
#
# 3. **User Training**: Provide training for healthcare providers and patients to ensure they understand how to use the platform effectively.
#
# 4. **Continuous Improvement**: Use feedback mechanisms to continually improve the platform based on user experiences and emerging healthcare trends.
#
# ### Expected Outcomes
#
# - **Improved Care Coordination**: Enhanced communication and collaboration among healthcare providers will lead to more cohesive and integrated patient care.
# - **Personalized Health Management**: Patients receive tailored recommendations and interventions, leading to better health outcomes and increased satisfaction with their care.
# - **Efficiency Gains**: Reduction in duplicated tests, unnecessary treatments, and administrative burdens will streamline healthcare delivery.
#
# The Unified Health Data Aggregator aims to solve the fragmentation issue in healthcare data management, empowering patients and providers to make informed, data-driven decisions that enhance care quality and personalize health management.
